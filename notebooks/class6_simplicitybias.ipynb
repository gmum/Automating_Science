# %% [markdown]
# Class Transformers

# %% [markdown]
# mem dystrybucja

# %% [markdown]
# transformery + induction head

# %% [markdown]
# prezka Staszka ze szkoły letniej https://docs.google.com/presentation/d/1_v-iOb2KHJ-GPQ3qh7MWjFa2I4cYZnKqqmzL13iwRnI/edit?usp=sharing_eil_se_dm&ts=65a00868

# %%
transformery mogą działać na zaszumionych danych. najpierw proste, potem uczy szumu
